# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',2000000)
df_climate = pd.read_csv("climate_test.csv")
df_climate = df_climate.drop(["original_url"], axis = 1)
df_edu = pd.read_csv("edu_test.csv")
df_edu = df_edu.drop(["original_url"], axis = 1)

# %%
df_edu.sample(frac=1)[0:3]
# Out:
#             logical_fallacies  \
# 18                  straw man
# 273      hasty generalization
# 267  cum hoc ergo propter hoc
#
#                                                                                                                                                                    source_article  \
# 18   Senator Smith says that the nation should not add to the defense budget. Senator Jones says that he cannot believe that Senator Smith wants to leave the nation defenseless.
# 273                              In both of the murder mysteries I have read, the District Attorney was the culprit. All mystery writers like to make lawyers out to be villains.
# 267                                                                          I'm moving to Connecticut because it is the richest state in the nation and I'm tired of being poor.
#
#     explanations  Rationale
# 18           NaN        NaN
# 273          NaN        NaN
# 267          NaN        NaN

# %%
df_climate[0:1]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
